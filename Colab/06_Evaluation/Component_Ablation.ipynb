# %% [markdown]
# # Component ablation

# %%
CONFIGURATIONS={
    "QA-only":{"kg":False,"retrieval":False,"llm":False,"routing":False},
    "QA+KG":{"kg":True,"retrieval":False,"llm":False,"routing":False},
    "QA+Document-Retrieval":{"kg":False,"retrieval":True,"llm":False,"routing":False},
    "QA+LLM":{"kg":False,"retrieval":False,"llm":True,"routing":False},
    "QA+LLM+Confidence-Routing":{"kg":False,"retrieval":False,"llm":True,"routing":True},
    "Full-EQAS":{"kg":True,"retrieval":True,"llm":True,"routing":True},
}
CONFIGURATIONS
